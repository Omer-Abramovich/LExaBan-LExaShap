# %%
import sys
sys.path.insert(0, "..")
from Algorithms.LExaBan.BanzhafCircuit import DNFCircuit as LExaBan
from Algorithms.LExaBan.Visualization import draw_dot

# %%
lineage = [
                {
                    "f8828ee3-f0e9-48db-8997-724fbd9af5eb",
                    "c0310eee-6755-4dd0-bcd8-7bbe415287cc",
                    "3c8b4989-84b8-4ae5-8af2-f97be247481f"
                },
                {
                    "f8828ee3-f0e9-48db-8997-724fbd9af5eb",
                    "c0310eee-6755-4dd0-bcd8-7bbe415287cc",
                    "882e6dc5-0628-456b-99ae-45b2d8cb4dd5"
                },
                {
                    "f8828ee3-f0e9-48db-8997-724fbd9af5eb",
                    "c0310eee-6755-4dd0-bcd8-7bbe415287cc",
                    "7ce17d37-0fa9-4cdb-bbf2-59e78876bf5f"
                },
                {
                    "f8828ee3-f0e9-48db-8997-724fbd9af5eb",
                    "c0310eee-6755-4dd0-bcd8-7bbe415287cc",
                    "b9152315-40cb-45f6-8b74-09ed762d995d"
                }
            ]
dtree = LExaBan(lineage)
draw_dot(dtree.root.value)
